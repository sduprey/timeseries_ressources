# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df.plot();

# %%
adfuller(df['Passengers'])
# Out:
# (0.8153688792060371,
#  0.9918802434376408,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
def adf(x):
  res = adfuller(x)
  print("Test-Statistic:", res[0])
  print("P-Value:", res[1])
  if res[1] < 0.05:
    print("Stationary")
  else:
    print("Non-Stationary")

# %%
adf(df['Passengers'])
# Out:
# Test-Statistic: 0.8153688792060371
# P-Value: 0.9918802434376408
# Non-Stationary

# %%
adf(np.random.randn(100))
# Out:
# Test-Statistic: -10.253258698103686
# P-Value: 4.4285605588473985e-18
# Stationary

# %%
df['LogPassengers'] = np.log(df['Passengers'])

# %%
adf(df['LogPassengers'])
# Out:
# Test-Statistic: -1.7170170891069634
# P-Value: 0.42236677477038986
# Non-Stationary

# %%
df['Diff'] = df['Passengers'].diff()

# %%
df['Diff'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
adf(df['Diff'].dropna())
# Out:
# Test-Statistic: -2.8292668241699945
# P-Value: 0.05421329028382621
# Non-Stationary

# %%
df['DiffLog'] = df['LogPassengers'].diff()

# %%
df['DiffLog'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
adf(df['DiffLog'].dropna())
# Out:
# Test-Statistic: -2.7171305983881138
# P-Value: 0.07112054815086194
# Non-Stationary

# %%
stocks = pd.read_csv('sp500sub.csv', index_col='Date', parse_dates=True)

# %%
stocks.head()
# Out:
#              Open   High    Low  Close  Adj Close     Volume  Name
# Date
# 2010-01-04   9.22   9.51   9.17   9.50       9.50  1865400.0  INCY
# 2010-01-05   9.51  10.29   9.45  10.27      10.27  7608900.0  INCY
# 2010-01-06  10.38  11.09  10.35  11.00      11.00  8046700.0  INCY
# 2010-01-07  11.00  11.06  10.62  10.82      10.82  3680300.0  INCY
# 2010-01-08  10.82  11.00  10.75  10.94      10.94  1529300.0  INCY

# %%
goog = stocks[stocks['Name'] == 'GOOG'][['Close']]

# %%
goog['LogPrice'] = np.log(goog['Close'])

# %%
goog['LogRet'] = goog['LogPrice'].diff()

# %%
goog['LogPrice'].plot();

# %%
goog['LogRet'].plot();

# %%
adf(goog['LogPrice'])
# Out:
# Test-Statistic: -0.4181902578906135
# P-Value: 0.9070170677498408
# Non-Stationary

# %%
adf(goog['LogRet'].dropna())
# Out:
# Test-Statistic: -46.667480227736746
# P-Value: 0.0
# Stationary

# %%
sbux = stocks[stocks['Name'] == 'SBUX'][['Close']]
sbux['LogPrice'] = np.log(sbux['Close'])
sbux['LogRet'] = sbux['LogPrice'].diff()

# %%
sbux['LogPrice'].plot();

# %%
sbux['LogRet'].plot();

# %%
adf(sbux['LogPrice'])
# Out:
# Test-Statistic: -1.902013358389997
# P-Value: 0.3311145569853776
# Non-Stationary

# %%
adf(sbux['LogRet'].dropna())
# Out:
# Test-Statistic: -30.086501426958097
# P-Value: 0.0
# Stationary
