# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from arch import arch_model

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# !pip install arch
# Out:
# Collecting arch
#   Obtaining dependency information for arch from https://files.pythonhosted.org/packages/b5/37/fb0d18e7d9d6510576430cb728c0ba41a3d4204c7f442ae57f543a266f0d/arch-6.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading arch-6.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from arch) (1.24.3)
# Requirement already satisfied: scipy>=1.5 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from arch) (1.11.1)
# Requirement already satisfied: pandas>=1.1 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from arch) (2.0.3)
# Requirement already satisfied: statsmodels>=0.12 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from arch) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->arch) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from pandas>=1.1->arch) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.12->arch) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.12->arch) (23.1)
# Requirement already satisfied: six in /Users/stefanduprey/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)
# Downloading arch-6.3.0-cp311-cp311-macosx_11_0_arm64.whl (929 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 929.0/929.0 kB 18.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: arch
# Successfully installed arch-6.3.0

# %%
df = pd.read_csv('SPY.csv', parse_dates=True, index_col='Date')

# %%
df.head()
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2010-01-04  112.370003  113.389999  111.510002  113.330002  92.246048
# 2010-01-05  113.260002  113.680000  112.849998  113.629997  92.490204
# 2010-01-06  113.519997  113.989998  113.430000  113.709999  92.555328
# 2010-01-07  113.500000  114.330002  113.180000  114.190002  92.946060
# 2010-01-08  113.889999  114.620003  113.660004  114.570000  93.255348
#
#                Volume
# Date
# 2010-01-04  118944600
# 2010-01-05  111579900
# 2010-01-06  116074400
# 2010-01-07  131091100
# 2010-01-08  126402800

# %%
df['LogRet'] = np.log(df['Close']).diff()

# %%
df2 = df.iloc[1:].copy()

# %%
df2['LogRet'].plot(figsize=(15, 5));

# %%
df2['Ysq'] = df['LogRet'] ** 2

# %%
df2['Ysq'].plot(figsize=(15, 5));

# %%
plot_acf(df2['LogRet']);

# %%
plot_pacf(df2['LogRet']);
# Out:
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df2['Ysq']);

# %%
plot_pacf(df2['Ysq']);
# Out:
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
noise_sq = np.random.randn(500)**2
plot_acf(noise_sq);

# %%
plot_pacf(noise_sq);
# Out:
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
Ntest = 500
train = df2.iloc[:-Ntest][['LogRet']].copy()
test = df2.iloc[-Ntest:][['LogRet']].copy()

# %%
model = arch_model(train['LogRet'], vol='GARCH', p=1, q=1)

# %%
res = model.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2668735021136.382
# Iteration:      2,   Func. Count:     19,   Neg. LLF: 6749790.867595025
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -5876.700716597365
#             Iterations: 3
#             Function evaluations: 27
#             Gradient evaluations: 2
# /Users/stefanduprey/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.532e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
m = train['LogRet'].mean()
s = train['LogRet'].std()
train['Scaled'] = (train['LogRet'] - m) / s
test['Scaled'] = (test['LogRet'] - m) / s
df2['Scaled'] = (df2['LogRet'] - m) / s

# %%
arch1 = arch_model(train['Scaled'], vol='ARCH', p=1)

# %%
res_arch1 = arch1.fit(update_freq=10)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2457.984028831199
#             Iterations: 6
#             Function evaluations: 32
#             Gradient evaluations: 6

# %%
res_arch1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                 Scaled   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -2457.98
# Distribution:                  Normal   AIC:                           4921.97
# Method:            Maximum Likelihood   BIC:                           4938.39
#                                         No. Observations:                 1762
# Date:                Fri, Jan 19 2024   Df Residuals:                     1761
# Time:                        13:45:22   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0127  2.325e-02      0.545      0.586 [-3.291e-02,5.825e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.8188  6.722e-02     12.181  3.936e-34   [  0.687,  0.951]
# alpha[1]       0.1771  4.774e-02      3.709  2.079e-04 [8.350e-02,  0.271]
# ==========================================================================
#
# Covariance estimator: robust
# """

# %%
df2['ARCH(1)'] = res_arch1.conditional_volatility
df2[['Scaled', 'ARCH(1)']].plot(figsize=(15, 5));

# %%
res_arch1.forecast(horizon=Ntest)
# Out:
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
fcast_arch1 = res_arch1.forecast(horizon=Ntest, reindex=True)

# %%
fcast_arch1

# %%
fcast_arch1.mean
# Out:
#                h.001     h.002     h.003     h.004     h.005     h.006  \
# Date
# 2010-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-11       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2016-12-27       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  0.012671  0.012671
#
#                h.007     h.008     h.009     h.010  ...     h.491     h.492  \
# Date                                                ...
# 2010-01-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-06       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-07       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-08       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2010-01-11       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2016-12-27       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2016-12-28       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2016-12-29       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2016-12-30       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  ...  0.012671  0.012671
#
#                h.493     h.494     h.495     h.496     h.497     h.498  \
# Date
# 2010-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-11       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2016-12-27       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-12-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  0.012671  0.012671
#
#                h.499     h.500
# Date
# 2010-01-05       NaN       NaN
# 2010-01-06       NaN       NaN
# 2010-01-07       NaN       NaN
# 2010-01-08       NaN       NaN
# 2010-01-11       NaN       NaN
# ...              ...       ...
# 2016-12-27       NaN       NaN
# 2016-12-28       NaN       NaN
# 2016-12-29       NaN       NaN
# 2016-12-30       NaN       NaN
# 2017-01-03  0.012671  0.012671
#
# [1762 rows x 500 columns]

# %%
fcast_arch1.variance
# Out:
#                h.001    h.002     h.003     h.004     h.005     h.006  \
# Date
# 2010-01-05       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-06       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-07       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-08       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-11       NaN      NaN       NaN       NaN       NaN       NaN
# ...              ...      ...       ...       ...       ...       ...
# 2016-12-27       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-29       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2017-01-03  0.912612  0.98042  0.992427  0.994553  0.994929  0.994996
#
#                h.007    h.008    h.009    h.010  ...    h.491    h.492  \
# Date                                             ...
# 2010-01-05       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-06       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-07       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-08       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-11       NaN      NaN      NaN      NaN  ...      NaN      NaN
# ...              ...      ...      ...      ...  ...      ...      ...
# 2016-12-27       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-28       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-29       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-30       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2017-01-03  0.995008  0.99501  0.99501  0.99501  ...  0.99501  0.99501
#
#               h.493    h.494    h.495    h.496    h.497    h.498    h.499  \
# Date
# 2010-01-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-06      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-07      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-08      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-11      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2016-12-27      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2017-01-03  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
#
#               h.500
# Date
# 2010-01-05      NaN
# 2010-01-06      NaN
# 2010-01-07      NaN
# 2010-01-08      NaN
# 2010-01-11      NaN
# ...             ...
# 2016-12-27      NaN
# 2016-12-28      NaN
# 2016-12-29      NaN
# 2016-12-30      NaN
# 2017-01-03  0.99501
#
# [1762 rows x 500 columns]

# %%
fcast_arch1.residual_variance
# Out:
#                h.001    h.002     h.003     h.004     h.005     h.006  \
# Date
# 2010-01-05       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-06       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-07       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-08       NaN      NaN       NaN       NaN       NaN       NaN
# 2010-01-11       NaN      NaN       NaN       NaN       NaN       NaN
# ...              ...      ...       ...       ...       ...       ...
# 2016-12-27       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-29       NaN      NaN       NaN       NaN       NaN       NaN
# 2016-12-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2017-01-03  0.912612  0.98042  0.992427  0.994553  0.994929  0.994996
#
#                h.007    h.008    h.009    h.010  ...    h.491    h.492  \
# Date                                             ...
# 2010-01-05       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-06       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-07       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-08       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2010-01-11       NaN      NaN      NaN      NaN  ...      NaN      NaN
# ...              ...      ...      ...      ...  ...      ...      ...
# 2016-12-27       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-28       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-29       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2016-12-30       NaN      NaN      NaN      NaN  ...      NaN      NaN
# 2017-01-03  0.995008  0.99501  0.99501  0.99501  ...  0.99501  0.99501
#
#               h.493    h.494    h.495    h.496    h.497    h.498    h.499  \
# Date
# 2010-01-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-06      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-07      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-08      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2010-01-11      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...      ...
# 2016-12-27      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2016-12-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2017-01-03  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
#
#               h.500
# Date
# 2010-01-05      NaN
# 2010-01-06      NaN
# 2010-01-07      NaN
# 2010-01-08      NaN
# 2010-01-11      NaN
# ...             ...
# 2016-12-27      NaN
# 2016-12-28      NaN
# 2016-12-29      NaN
# 2016-12-30      NaN
# 2017-01-03  0.99501
#
# [1762 rows x 500 columns]

# %%
fcast_arch1 = res_arch1.forecast(horizon=Ntest, reindex=False)

# %%
fcast_arch1.mean
# Out:
#                h.001     h.002     h.003     h.004     h.005     h.006  \
# Date
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  0.012671  0.012671
#
#                h.007     h.008     h.009     h.010  ...     h.491     h.492  \
# Date                                                ...
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  ...  0.012671  0.012671
#
#                h.493     h.494     h.495     h.496     h.497     h.498  \
# Date
# 2017-01-03  0.012671  0.012671  0.012671  0.012671  0.012671  0.012671
#
#                h.499     h.500
# Date
# 2017-01-03  0.012671  0.012671
#
# [1 rows x 500 columns]

# %%
fcast_arch1.variance
# Out:
#                h.001    h.002     h.003     h.004     h.005     h.006  \
# Date
# 2017-01-03  0.912612  0.98042  0.992427  0.994553  0.994929  0.994996
#
#                h.007    h.008    h.009    h.010  ...    h.491    h.492  \
# Date                                             ...
# 2017-01-03  0.995008  0.99501  0.99501  0.99501  ...  0.99501  0.99501
#
#               h.493    h.494    h.495    h.496    h.497    h.498    h.499  \
# Date
# 2017-01-03  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
#
#               h.500
# Date
# 2017-01-03  0.99501
#
# [1 rows x 500 columns]

# %%
df2.loc['2011-08-09':]['ARCH(1)'].plot(figsize=(15, 5));

# %%
fcast_arch1 = res_arch1.forecast(
    horizon=Ntest, reindex=True, start='2011-08-01')

# %%
fcast_arch1.variance['2011-07-28':'2011-08-05']
# Out:
#                h.001     h.002     h.003     h.004     h.005     h.006  \
# Date
# 2011-07-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-07-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-08-01  0.861165  0.971311  0.990814  0.994267  0.994879  0.994987
# 2011-08-02  2.112095  1.192807  1.030033  1.001211  0.996108  0.995205
# 2011-08-03  0.863233  0.971677  0.990879  0.994279  0.994881  0.994987
# 2011-08-04  5.183712  1.736683  1.126334  1.018263  0.999127  0.995739
# 2011-08-05  0.826340  0.965145  0.989722  0.994074  0.994844  0.994981
#
#                h.007     h.008     h.009     h.010  ...    h.491    h.492  \
# Date                                                ...
# 2011-07-28       NaN       NaN       NaN       NaN  ...      NaN      NaN
# 2011-07-29       NaN       NaN       NaN       NaN  ...      NaN      NaN
# 2011-08-01  0.995006  0.995009  0.995010  0.995010  ...  0.99501  0.99501
# 2011-08-02  0.995045  0.995016  0.995011  0.995010  ...  0.99501  0.99501
# 2011-08-03  0.995006  0.995009  0.995010  0.995010  ...  0.99501  0.99501
# 2011-08-04  0.995139  0.995033  0.995014  0.995011  ...  0.99501  0.99501
# 2011-08-05  0.995005  0.995009  0.995010  0.995010  ...  0.99501  0.99501
#
#               h.493    h.494    h.495    h.496    h.497    h.498    h.499  \
# Date
# 2011-07-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2011-07-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2011-08-01  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
# 2011-08-02  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
# 2011-08-03  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
# 2011-08-04  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
# 2011-08-05  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501  0.99501
#
#               h.500
# Date
# 2011-07-28      NaN
# 2011-07-29      NaN
# 2011-08-01  0.99501
# 2011-08-02  0.99501
# 2011-08-03  0.99501
# 2011-08-04  0.99501
# 2011-08-05  0.99501
#
# [7 rows x 500 columns]

# %%
fcast_arch1.variance.loc['2011-08-09'].to_numpy().shape
# Out:
# (500,)

# %%
df2.index.get_loc('2011-08-09')
# Out:
# 402

# %%
df2.index[402 + 500]
# Out:
# Timestamp('2013-08-06 00:00:00')

# %%
df2.loc['2011-08-10':'2013-08-06', 'ARCH(1) Forecast'] = np.sqrt(
    fcast_arch1.variance.loc['2011-08-09'].to_numpy())

# %%
df2.loc['2011-08-01':'2012-02-01'][['ARCH(1)', 'ARCH(1) Forecast']].plot(
    figsize=(15, 5));

# %%
fcast_arch1.variance.index.get_loc('2011-08-17')
# Out:
# 408

# %%
df2.index[408 + 500]
# Out:
# Timestamp('2013-08-14 00:00:00')

# %%
df2.loc['2011-08-18':'2013-08-14', 'ARCH(1) Forecast Low'] = np.sqrt(
    fcast_arch1.variance.loc['2011-08-17'].to_numpy())

# %%
plot_cols = ['ARCH(1) Forecast', 'ARCH(1) Forecast Low']
df2.loc['2011-08-01':'2012-02-01'][plot_cols].plot(figsize=(15, 5));

# %%
# theoretical unconditional variance
res_arch1.params
# Out:
# mu          0.012671
# omega       0.818829
# alpha[1]    0.177065
# Name: params, dtype: float64

# %%
res_arch1.params['omega'] / (1 - res_arch1.params['alpha[1]'])
# Out:
# 0.99501008483029

# %%
fcast_arch1.variance.loc['2011-08-17'].to_numpy()[-1]
# Out:
# 0.9950100848302899

# %%
fcast_arch1.variance.loc['2011-08-09'].to_numpy()[-1]
# Out:
# 0.9950100848302899

# %%
garch11 = arch_model(train['Scaled'], vol='GARCH', p=1, q=1)

# %%
res_garch11 = garch11.fit(update_freq=10)
# Out:
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 2269.107952001976
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2269.107941826097
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12

# %%
res_garch11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Scaled   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2269.11
# Distribution:                  Normal   AIC:                           4546.22
# Method:            Maximum Likelihood   BIC:                           4568.11
#                                         No. Observations:                 1762
# Date:                Fri, Jan 19 2024   Df Residuals:                     1761
# Time:                        13:50:23   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0287  1.865e-02      1.538      0.124 [-7.863e-03,6.525e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0469  1.060e-02      4.427  9.560e-06 [2.615e-02,6.770e-02]
# alpha[1]       0.1499  2.499e-02      6.000  1.972e-09     [  0.101,  0.199]
# beta[1]        0.8021  2.545e-02     31.516 5.232e-218     [  0.752,  0.852]
# ============================================================================
#
# Covariance estimator: robust
# """

# %%
df2['GARCH(1,1)'] = res_garch11.conditional_volatility
df2[['Scaled', 'ARCH(1)', 'GARCH(1,1)']].plot(figsize=(15, 5));

# %%
fcast_garch11 = res_garch11.forecast(
    horizon=Ntest, reindex=False, start='2011-08-09')
df2.loc['2011-08-10':'2013-08-06', 'GARCH(1,1) Forecast'] = np.sqrt(
    fcast_garch11.residual_variance.loc['2011-08-09'].to_numpy())
df2['AbsScaled'] = df2['Scaled'].abs()

plot_cols = ['AbsScaled', 'ARCH(1) Forecast', 'GARCH(1,1) Forecast']
df2.loc['2011-08-01':'2012-02-01'][plot_cols].plot(figsize=(15, 5));

# %%
garch11t = arch_model(train['Scaled'], vol='GARCH', p=1, q=1, dist='StudentsT')

# %%
res_garch11t = garch11t.fit(update_freq=10)
# Out:
# Iteration:     10,   Func. Count:     74,   Neg. LLF: 2230.1829850072672
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2230.179786590769
#             Iterations: 14
#             Function evaluations: 97
#             Gradient evaluations: 14

# %%
res_garch11t.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                       Scaled   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -2230.18
# Distribution:      Standardized Student's t   AIC:                           4470.36
# Method:                  Maximum Likelihood   BIC:                           4497.73
#                                               No. Observations:                 1762
# Date:                      Fri, Jan 19 2024   Df Residuals:                     1761
# Time:                              13:54:23   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0471  1.691e-02      2.788  5.309e-03 [1.400e-02,8.028e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0399  9.295e-03      4.296  1.742e-05 [2.171e-02,5.815e-02]
# alpha[1]       0.1615  2.507e-02      6.442  1.180e-10     [  0.112,  0.211]
# beta[1]        0.8081  2.353e-02     34.350 1.427e-258     [  0.762,  0.854]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             5.5803      0.733      7.610  2.735e-14 [  4.143,  7.017]
# ========================================================================
#
# Covariance estimator: robust
# """

# %%
df2['GARCH(1,1)t'] = res_garch11t.conditional_volatility
df2[['Scaled', 'GARCH(1,1)t', 'GARCH(1,1)']].plot(figsize=(15, 5));

# %%
fcast_garch11t = res_garch11t.forecast(
    horizon=Ntest, reindex=False, start='2011-08-09')

# %%
df2.loc['2011-08-10':'2013-08-06', 'GARCH(1,1)t Forecast'] = np.sqrt(
    fcast_garch11t.residual_variance.loc['2011-08-09'].to_numpy())

# %%
plot_cols = ['AbsScaled', 'GARCH(1,1)t Forecast', 'GARCH(1,1) Forecast']
df2.loc['2011-08-01':'2012-02-01'][plot_cols].plot(figsize=(15, 5));

# %%
garchpq = arch_model(train['Scaled'], p=8, q=5, dist='StudentsT')

# %%
res_garchpq = garchpq.fit(update_freq=10)
# Out:
# Iteration:     10,   Func. Count:    186,   Neg. LLF: 2614.0817265255996
# Iteration:     20,   Func. Count:    369,   Neg. LLF: 2224.51850231079
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2224.2181169584296
#             Iterations: 29
#             Function evaluations: 522
#             Gradient evaluations: 29

# %%
res_garchpq.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                       Scaled   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -2224.22
# Distribution:      Standardized Student's t   AIC:                           4480.44
# Method:                  Maximum Likelihood   BIC:                           4568.02
#                                               No. Observations:                 1762
# Date:                      Fri, Jan 19 2024   Df Residuals:                     1761
# Time:                              13:56:57   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0483  1.715e-02      2.817  4.846e-03 [1.470e-02,8.192e-02]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.1008  5.518e-02      1.826  6.781e-02 [-7.377e-03,  0.209]
# alpha[1]       0.0744  3.351e-02      2.220  2.643e-02  [8.710e-03,  0.140]
# alpha[2]       0.1687  6.306e-02      2.675  7.466e-03  [4.511e-02,  0.292]
# alpha[3]       0.0000      0.108      0.000      1.000    [ -0.212,  0.212]
# alpha[4]       0.0116  9.806e-02      0.118      0.906    [ -0.181,  0.204]
# alpha[5]       0.0370  7.043e-02      0.526      0.599    [ -0.101,  0.175]
# alpha[6]       0.0277  5.506e-02      0.503      0.615 [-8.024e-02,  0.136]
# alpha[7]       0.0145  6.710e-02      0.216      0.829    [ -0.117,  0.146]
# alpha[8]       0.0381  5.692e-02      0.670      0.503 [-7.341e-02,  0.150]
# beta[1]        0.5490      0.499      1.101      0.271    [ -0.429,  1.526]
# beta[2]        0.0000      0.622      0.000      1.000    [ -1.219,  1.219]
# beta[3]        0.0000      0.549      0.000      1.000    [ -1.075,  1.075]
# beta[4]        0.0000      0.354      0.000      1.000    [ -0.693,  0.693]
# beta[5]        0.0000      0.346      0.000      1.000    [ -0.679,  0.679]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             5.7008      0.772      7.386  1.511e-13 [  4.188,  7.214]
# ========================================================================
#
# Covariance estimator: robust
# """

# %%
res_arch1.aic, res_garch11.aic, res_garch11t.aic, res_garchpq.aic
# Out:
# (4921.968057662398, 4546.215883652194, 4470.359573181538, 4480.436233916859)

# %%
df2['GARCH(p,q)'] = res_garchpq.conditional_volatility
df2[['Scaled', 'GARCH(1,1)t', 'GARCH(p,q)']].plot(figsize=(15, 5));

# %%
fcast_garchpq = res_garchpq.forecast(
    horizon=Ntest, reindex=False, start='2011-08-09')
df2.loc['2011-08-10':'2013-08-06', 'GARCH(p,q) Forecast'] = np.sqrt(
    fcast_garch11t.variance.loc['2011-08-09'].to_numpy())
plot_cols = ['AbsScaled', 'GARCH(1,1)t Forecast', 'GARCH(p,q) Forecast']
df2.loc['2011-08-01':'2012-02-01'][plot_cols].plot(figsize=(15, 5));

# %%
train_idx = df2.index <= train.index[-1]
test_idx = ~train_idx
df2.loc[train_idx, 'GARCH(p,q) Train'] = res_garchpq.conditional_volatility
df2.loc[test_idx, 'GARCH(p,q) Test'] = np.sqrt(
    fcast_garchpq.variance.iloc[-1].to_numpy())
plot_cols = ['AbsScaled', 'GARCH(p,q) Train', 'GARCH(p,q) Test']
df2.iloc[-(Ntest+100):][plot_cols].plot(figsize=(15, 5));
