# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
r = np.array(range(0,100,1))
r=r/100
data_df = pd.DataFrame(data = {
    'r':r
})
for p in [1,2,3,10,100]:
    y = np.power(r, 1./p)
    data_df[f'dim_{p}']=y

# %%
data_df=data_df.set_index(r)

# %%
data_df.plot()
# Out:
# <Axes: >
