# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score

# %%
df = pd.read_csv(
    '../DataSets/perrin-freres-monthly-champagne.csv',
    index_col='Month',
    skipfooter=2,
    parse_dates=True)
# Out:
# /var/folders/pm/717hp7y52f1gx9gr4nnn727m0000gn/T/ipykernel_33508/2118373962.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(

# %%
df.head()
# Out:
#             Perrin Freres monthly champagne sales millions ?64-?72
# Month
# 1964-01-01                                               2815
# 1964-02-01                                               2672
# 1964-03-01                                               2755
# 1964-04-01                                               2721
# 1964-05-01                                               2946

# %%
df.columns = ['Sales']

# %%
df['Sales'].plot();

# %%
df['LogSales'] = np.log(df['Sales'])
df['LogSales'].plot();

# %%
df.index.freq = 'MS'

# %%
Ntest = 12
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading cython-3.1.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in /opt/anaconda3/lib/python3.12/site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.5 MB/s eta 0:00:00
# Downloading cython-3.1.5-cp312-cp312-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.1.5 pmdarima-2.0.4

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(train['LogSales'],
                      trace=True,
                      suppress_warnings=True,
                      seasonal=True, m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-50.381, Time=0.69 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-41.975, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-54.968, Time=0.13 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-53.384, Time=0.17 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-34.700, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=-44.102, Time=0.01 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=-52.971, Time=0.45 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=-52.991, Time=0.16 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-55.117, Time=0.12 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=-53.123, Time=0.32 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-50.817, Time=0.12 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-56.122, Time=0.18 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-44.178, Time=0.05 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-54.128, Time=0.53 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-54.125, Time=0.40 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-55.720, Time=0.12 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=1.13 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-55.723, Time=0.21 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-55.836, Time=0.25 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-57.834, Time=0.29 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-45.579, Time=0.09 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-55.842, Time=0.81 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-55.838, Time=0.76 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-57.407, Time=0.22 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-55.039, Time=1.08 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-55.850, Time=0.39 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-53.608, Time=0.15 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-52.180, Time=1.03 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=-56.684, Time=0.23 sec
#
# Best model:  ARIMA(1,0,1)(0,1,1)[12] intercept
# Total fit time: 10.934 seconds

# %%
# Since the model is seasonal, we won't plot or predict the first 12
# values (since pmdarima will set them to 0)
train_pred = model.predict_in_sample(start=12, end=-1)
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogSales'], label='data')
ax.plot(train.index[12:], train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
# Compute R^2
r2_score(test['Sales'], np.exp(test_pred))
# Out:
# 0.9546544335633822

# %%
# Best non-seasonal model
model = pm.auto_arima(train['LogSales'],
                      trace=True,
                      max_p=12, max_q=2, max_order=14,
                      suppress_warnings=True,
                      stepwise=False,
                      seasonal=False)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=141.911, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=141.540, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=139.851, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=138.023, Time=0.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=114.336, Time=0.04 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=114.576, Time=0.11 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=114.173, Time=0.06 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=116.168, Time=0.13 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=116.155, Time=0.11 sec
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=118.024, Time=0.12 sec
#  ARIMA(6,1,2)(0,0,0)[0] intercept   : AIC=106.531, Time=0.31 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=112.569, Time=0.09 sec
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=104.790, Time=0.37 sec
#  ARIMA(7,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=85.830, Time=0.21 sec
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=56.518, Time=0.37 sec
#  ARIMA(8,1,2)(0,0,0)[0] intercept   : AIC=36.790, Time=0.43 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=83.083, Time=1.00 sec
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=56.843, Time=0.57 sec
#  ARIMA(9,1,2)(0,0,0)[0] intercept   : AIC=60.427, Time=0.55 sec
#  ARIMA(10,1,0)(0,0,0)[0] intercept   : AIC=65.099, Time=0.32 sec
#  ARIMA(10,1,1)(0,0,0)[0] intercept   : AIC=38.178, Time=0.58 sec
#  ARIMA(10,1,2)(0,0,0)[0] intercept   : AIC=13.082, Time=0.62 sec
#  ARIMA(11,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(11,1,1)(0,0,0)[0] intercept   : AIC=-16.316, Time=0.55 sec
#  ARIMA(11,1,2)(0,0,0)[0] intercept   : AIC=-17.513, Time=0.83 sec
#  ARIMA(12,1,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(12,1,1)(0,0,0)[0] intercept   : AIC=-19.792, Time=0.85 sec
#  ARIMA(12,1,2)(0,0,0)[0] intercept   : AIC=-17.775, Time=0.87 sec
#
# Best model:  ARIMA(12,1,1)(0,0,0)[0] intercept
# Total fit time: 12.614 seconds

# %%
train_pred = model.predict_in_sample(start=1, end=-1)
test_pred, confint = model.predict(n_periods=Ntest, return_conf_int=True)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df.index, df['LogSales'], label='data')
ax.plot(train.index[1:], train_pred, label='fitted')
ax.plot(test.index, test_pred, label='forecast')
ax.fill_between(test.index, \
                confint[:,0], confint[:,1], \
                color='red', alpha=0.3)
ax.legend();

# %%
r2_score(test['Sales'], np.exp(test_pred))
# Out:
# 0.9726102758157408

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['LogSales']);

# %%
# You'll get a weird sqrt error with default method
plot_pacf(df['LogSales'], method='ols');

# %%
df['LogSales'].diff().plot();

# %%
plot_acf(df['LogSales'].diff().dropna());

# %%
plot_pacf(df['LogSales'].diff().dropna(), method='ols');

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df['LogSales'])
# Out:
# (-2.2551186012844506,
#  0.1868517311168651,
#  13,
#  91,
#  {'1%': -3.50434289821397,
#   '5%': -2.8938659630479413,
#   '10%': -2.5840147047458037},
#  -49.19143751582999)

# %%
adfuller(df['LogSales'].diff().dropna())
# Out:
# (-4.460914465253696,
#  0.000231214046495299,
#  12,
#  91,
#  {'1%': -3.50434289821397,
#   '5%': -2.8938659630479413,
#   '10%': -2.5840147047458037},
#  -43.63799632128652)

# %%
# from previous
def plot_fit_and_forecast(result, d=0, col='Sales'):
  fig, ax = plt.subplots(figsize=(10, 5))
  ax.plot(df[col], label='data')

  # plot the curve fitted on train set
  train_pred = result.fittedvalues
  ax.plot(train.index[d:], train_pred[d:], color='green', label='fitted')

  # forecast the test set
  prediction_result = result.get_forecast(Ntest)
  conf_int = prediction_result.conf_int()
  lower, upper = conf_int[f'lower {col}'], conf_int[f'upper {col}']
  forecast = prediction_result.predicted_mean
  ax.plot(test.index, forecast, label='forecast')
  ax.fill_between(test.index, \
                  lower, upper, \
                  color='red', alpha=0.3)
  ax.legend()

  return forecast

# %%
arima = ARIMA(train['LogSales'], order=(12,1,2))
arima_result = arima.fit()
forecast = plot_fit_and_forecast(arima_result, d=1, col='LogSales')
# Out:
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/stefanduprey/opt/miniconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
r2_score(test['Sales'], np.exp(forecast))
# Out:
# 0.9866591927603712
