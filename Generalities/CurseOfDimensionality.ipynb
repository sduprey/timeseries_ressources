# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
r = np.array(range(0,100,1))
r=r/100
data_df = pd.DataFrame(data = {
    'r':r
})
for p in [1,2,3,10,100]:
    y = np.power(r, 1./p)
    data_df[f'dim_{p}']=y

# %%
data_df=data_df.set_index(r)

# %%
data_df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm
from matplotlib.ticker import LinearLocator

# Make data.
X = np.arange(-3, 3, 0.25)
Y = np.arange(-3, 3, 0.25)
X, Y = np.meshgrid(X, Y)

Z=np.cos(2*X)+np.cos(3*Y)

X.shape
print(X[0][0])
print(X[23][23])
# Out:
# -3.0
# 2.75

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

print(X.shape)
print(Y.shape)
print(Z.shape)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# (24, 24)
# (24, 24)
# (24, 24)

# %%
# Plot it
X = np.random.random(200)*6-3
Y = np.random.random(200)*6-3
Z=np.cos(2*X)+np.cos(3*Y)

fig = plt.figure(figsize=(20, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X, Y, Z);

# %%
xx, yy = np.meshgrid(np.sort(X),np.sort( Y))

zz =np.cos(2*xx)+np.cos(3*yy)

print(xx.shape)
print(yy.shape)
print(zz.shape)
# Out:
# (200, 200)
# (200, 200)
# (200, 200)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})


# Plot the surface.
surf = ax.plot_surface(xx, yy, zz, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
